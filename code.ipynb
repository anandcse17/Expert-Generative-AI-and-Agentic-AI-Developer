# %%
10 // 2
# Out:
# 5

# %%
10 / 2
# Out:
# 5.0

# %%
3 ** 3
# Out:
# 27

# %%
(2+3)-8
# Out:
# -3

# %%
3 * 3
# Out:
# 9

# %%
2+3
# Out:
# 5

# %%
'Welcome to the world of Python programming!    '
# Out:
# 'Welcome to the world of Python programming!    '
